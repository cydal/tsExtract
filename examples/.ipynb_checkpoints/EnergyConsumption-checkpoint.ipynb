# %% [markdown]
# <a href="https://colab.research.google.com/github/cydal/tsExtract/blob/master/EnergyConsumption.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
### https://www.kaggle.com/robikscube/hourly-energy-consumption?select=NI_hourly.csv

# %%
import pandas as pd
import numpy as np

import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
import scipy.stats

import sys
sys.path.append('../tsextract')


from feature_extraction.extract import build_features
from domain.statistics import median, mean, skew, kurtosis
from plots.eval import get_lag_corr, actualPred, scatter

import xgboost

# %%
df = pd.read_csv("DAYTON_hourly.csv")
df["Datetime"] = pd.to_datetime(df["Datetime"])
df = df.set_index("Datetime")

# %%
##sys.path.append('../tsextract/scripts')

# %%
df
# Out:
#                      DAYTON_MW
# Datetime
# 2004-12-31 01:00:00     1596.0
# 2004-12-31 02:00:00     1517.0
# 2004-12-31 03:00:00     1486.0
# 2004-12-31 04:00:00     1469.0
# 2004-12-31 05:00:00     1472.0
# ...                        ...
# 2018-01-01 20:00:00     2732.0
# 2018-01-01 21:00:00     2724.0
# 2018-01-01 22:00:00     2664.0
# 2018-01-01 23:00:00     2614.0
# 2018-01-02 00:00:00     2552.0
#
# [121275 rows x 1 columns]

# %%
df["DAYTON_MW"].shift(1)
# Out:
# Datetime
# 2004-12-31 01:00:00       NaN
# 2004-12-31 02:00:00    1596.0
# 2004-12-31 03:00:00    1517.0
# 2004-12-31 04:00:00    1486.0
# 2004-12-31 05:00:00    1469.0
#                         ...
# 2018-01-01 20:00:00    2714.0
# 2018-01-01 21:00:00    2732.0
# 2018-01-01 22:00:00    2724.0
# 2018-01-01 23:00:00    2664.0
# 2018-01-02 00:00:00    2614.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
df["DAYTON_MW"].plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
df["DAYTON_MW"][df.index.year == 2005].plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
df["DAYTON_MW"][((df.index.year == 2006) & (df.index.month == 2))].plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
## We can see both seasonality and Trend.

# %%
df[["DAYTON_MW"]].rolling(8760).mean().plot(figsize=(20,10), linewidth=2, fontsize=20)

# %%
df["DAYTON_MW"].resample('D').mean().plot(figsize=(20,10), linewidth=2, fontsize=20)

# %%
df["DAYTON_MW"][((df.index.year == 2006) & (df.index.month == 1))].diff().plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
df["DAYTON_MW"][((df.index.year == 2007) & 
                 (df.index.month == 1) & 
                 (df.index.day == 1))].diff().plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
df["DAYTON_MW"][((df.index.year == 2018) & 
                 (df.index.month == 1) & 
                 (df.index.day == 1))].diff().plot(figsize=(20,10), linewidth=5, fontsize=20)

# %%
index = df.index
win_24 = window_list(df["DAYTON_MW"], [10, 24])

# %%
win_24.shape
# Out:
# (121275, 14)

# %%
df["DAYTON_MW"] #t+0 t+18 t+18 - 1+0
# Out:
# Datetime
# 2004-12-31 01:00:00    1596.0
# 2004-12-31 02:00:00    1517.0
# 2004-12-31 03:00:00    1486.0
# 2004-12-31 04:00:00    1469.0
# 2004-12-31 05:00:00    1472.0
#                         ...
# 2018-01-01 20:00:00    2732.0
# 2018-01-01 21:00:00    2724.0
# 2018-01-01 22:00:00    2664.0
# 2018-01-01 23:00:00    2614.0
# 2018-01-02 00:00:00    2552.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
difference(df["DAYTON_MW"], 1)
# Out:
# Datetime
# 2004-12-31 01:00:00     NaN
# 2004-12-31 02:00:00   -79.0
# 2004-12-31 03:00:00   -31.0
# 2004-12-31 04:00:00   -17.0
# 2004-12-31 05:00:00     3.0
#                        ...
# 2018-01-01 20:00:00    18.0
# 2018-01-01 21:00:00    -8.0
# 2018-01-01 22:00:00   -60.0
# 2018-01-01 23:00:00   -50.0
# 2018-01-02 00:00:00   -62.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
win_24_mean = win_stat(win_24, "mean")
win_24_diff = difference_comb(df["DAYTON_MW"], [24, 10])
win_24_diff.shape 



#####
# Out:
# (121275, 14)

# %%
combined_df = np.hstack((win_24, # Windowed Data -> 24
           win_24_mean, # Windowed Data MEAN -> 1
           win_24_diff, # Windowed Data DIFF  - 25 - 10 -> 14
           np.expand_dims(df["DAYTON_MW"], axis=1), # T+0 -> 1
           np.expand_dims(df["DAYTON_MW"].shift(-18), axis=1))) # T + 18 Target -> 1


combined_df.shape # 24 + 14 + 1 + 1 + 1 = 41
# Out:
# (121275, 41)

# %%
## Difference Network - is not raw value
## Difference feature

# %%
features_request = {
    "window":[10, 24], ## Look into 
    "window_statistic":[10, 20, "median"], 
    "difference":[10, 24, 10], #window_size and lag - ## Look into 
    "momentum_statistic":[10, 24, 10, "mean"], # window_size, lag, statistic
    "force_statistic":[10, 24, 10, "std"], 
}

# %%
features_request = {
    "window":[10, 24], ## Look into 
    "window_statistic":[10, 20, "median"], 
    "difference":[10, 24, 10], #window_size and lag - ## Look into 
    "momentum_statistic":[10, 24, 10, "mean"], # window_size, lag, statistic
    "force_statistic":[10, 24, 10, "std"], 
}

# %%
features_request = {
    "window":[10, 24], ## Look into -- # 10
    "window_statistic":[10, 20, "median"],
    "difference":[5, 15, 10], #window_size and lag - ## Look into 
    "momentum":[5, 15, 10],
    "force":[6, 15, 10]
}

# %%
features_request = {
    "window":[10], ## Look into -- # 10
    "window_statistic":[10, 24, median], # 1
    "difference":[5, 15, 10], #window_size and lag - ## Look into 
    "momentum":[5, 15, 10],
    "force":[6, 15, 10],
    "difference_statistic":[12, 15, 10, mean], # 1
    "momentum_statistic":[13, 15, 10, mean], # 1
    "force_statistic":[12, 15, 10, mean], # window_size, lag, statistic
}

# %%
features = build_features(df["DAYTON_MW"], features_request, target_lag=3, include_tzero=True)

# %%
features
# Out:
#                        T-10     T-9     T-8     T-7     T-6     T-5     T-4  \
# Date
# 2004-12-30 01:00:00  1829.0  1807.0  1838.0  1945.0  1968.0  1867.0  1785.0
# 2004-12-30 02:00:00  1807.0  1838.0  1945.0  1968.0  1867.0  1785.0  1711.0
# 2004-12-30 03:00:00  1838.0  1945.0  1968.0  1867.0  1785.0  1711.0  1639.0
# 2004-12-30 04:00:00  1945.0  1968.0  1867.0  1785.0  1711.0  1639.0  1560.0
# 2004-12-30 05:00:00  1968.0  1867.0  1785.0  1711.0  1639.0  1560.0  1713.0
# ...                     ...     ...     ...     ...     ...     ...     ...
# 2018-01-01 17:00:00  2337.0  2400.0  2427.0  2452.0  2481.0  2480.0  2454.0
# 2018-01-01 18:00:00  2400.0  2427.0  2452.0  2481.0  2480.0  2454.0  2419.0
# 2018-01-01 19:00:00  2427.0  2452.0  2481.0  2480.0  2454.0  2419.0  2372.0
# 2018-01-01 20:00:00  2452.0  2481.0  2480.0  2454.0  2419.0  2372.0  2384.0
# 2018-01-01 21:00:00  2481.0  2480.0  2454.0  2419.0  2372.0  2384.0  2441.0
#
#                         T-3     T-2     T-1  window_statistic_10_24_median  \
# Date
# 2004-12-30 01:00:00  1711.0  1639.0  1560.0                         1644.5
# 2004-12-30 02:00:00  1639.0  1560.0  1713.0                         1719.5
# 2004-12-30 03:00:00  1560.0  1713.0  1647.0                         1777.5
# 2004-12-30 04:00:00  1713.0  1647.0  1611.0                         1816.0
# 2004-12-30 05:00:00  1647.0  1611.0  1608.0                         1827.0
# ...                     ...     ...     ...                            ...
# 2018-01-01 17:00:00  2419.0  2372.0  2384.0                         2708.0
# 2018-01-01 18:00:00  2372.0  2384.0  2441.0                         2505.5
# 2018-01-01 19:00:00  2384.0  2441.0  2617.0                         2368.5
# 2018-01-01 20:00:00  2441.0  2617.0  2714.0                         2368.5
# 2018-01-01 21:00:00  2617.0  2714.0  2732.0                         2368.5
#
#                      difference_5_15_10-1  momentum_5_15_10-1  \
# Date
# 2004-12-30 01:00:00                -116.0              -473.0
# 2004-12-30 02:00:00                -160.0              -449.0
# 2004-12-30 03:00:00                -227.0              -467.0
# 2004-12-30 04:00:00                -337.0              -591.0
# 2004-12-30 05:00:00                -338.0              -558.0
# ...                                   ...                 ...
# 2018-01-01 17:00:00                 104.0               699.0
# 2018-01-01 18:00:00                 217.0               682.0
# 2018-01-01 19:00:00                 287.0               631.0
# 2018-01-01 20:00:00                 280.0               502.0
# 2018-01-01 21:00:00                 243.0                68.0
#
#                      force_6_15_10-1  difference_statistic_12_15_10_mean  \
# Date
# 2004-12-30 01:00:00           -116.0                              -116.0
# 2004-12-30 02:00:00           -160.0                              -160.0
# 2004-12-30 03:00:00           -227.0                              -227.0
# 2004-12-30 04:00:00           -337.0                              -337.0
# 2004-12-30 05:00:00           -338.0                              -338.0
# ...                              ...                                 ...
# 2018-01-01 17:00:00            104.0                               104.0
# 2018-01-01 18:00:00            217.0                               217.0
# 2018-01-01 19:00:00            287.0                               287.0
# 2018-01-01 20:00:00            280.0                               280.0
# 2018-01-01 21:00:00            243.0                               243.0
#
#                      momentum_statistic_13_15_10_mean  \
# Date
# 2004-12-30 01:00:00                            -473.0
# 2004-12-30 02:00:00                            -449.0
# 2004-12-30 03:00:00                            -467.0
# 2004-12-30 04:00:00                            -591.0
# 2004-12-30 05:00:00                            -558.0
# ...                                               ...
# 2018-01-01 17:00:00                             699.0
# 2018-01-01 18:00:00                             682.0
# 2018-01-01 19:00:00                             631.0
# 2018-01-01 20:00:00                             502.0
# 2018-01-01 21:00:00                              68.0
#
#                      force_statistic_12_15_10_mean   tzero  Target_Tplus3
# Date
# 2004-12-30 01:00:00                         -116.0  1713.0         1608.0
# 2004-12-30 02:00:00                         -160.0  1647.0         1630.0
# 2004-12-30 03:00:00                         -227.0  1611.0         1704.0
# 2004-12-30 04:00:00                         -337.0  1608.0         1839.0
# 2004-12-30 05:00:00                         -338.0  1630.0         1986.0
# ...                                            ...     ...            ...
# 2018-01-01 17:00:00                          104.0  2441.0         2732.0
# 2018-01-01 18:00:00                          217.0  2617.0         2724.0
# 2018-01-01 19:00:00                          287.0  2714.0         2664.0
# 2018-01-01 20:00:00                          280.0  2732.0         2614.0
# 2018-01-01 21:00:00                          243.0  2724.0         2552.0
#
# [121248 rows x 19 columns]

# %%
features.shape
# Out:
# (121248, 19)

# %%
train_size = int(features.shape[0] * 0.8)

x_train, y_train = features.iloc[:train_size, :-2], features.iloc[:train_size, -1]
x_test, y_test = features.iloc[train_size:, :-2], features.iloc[train_size:, -1]

# %%
model = xgboost.XGBRegressor(colsample_bytree=0.4,
                 objective="reg:squarederror",
                 gamma=0,                 
                 learning_rate=0.07,
                 max_depth=3,
                 min_child_weight=1.5,
                 n_estimators=100,                                                                    
                 reg_alpha=0.75,
                 reg_lambda=0.45,
                 subsample=0.6,
                 seed=42)

# %%
model.fit(x_train, y_train)
# Out:
# XGBRegressor(colsample_bytree=0.4, learning_rate=0.07, min_child_weight=1.5,
#              objective='reg:squarederror', reg_alpha=0.75, reg_lambda=0.45,
#              seed=42, subsample=0.6)

# %%
pred = model.predict(x_test)

# %%
mean_squared_error(y_train, model.predict(x_train))
# Out:
# 21597.514601870647

# %%
mean_squared_error(y_test, model.predict(x_test))
# Out:
# 21701.21250346431

# %%
scatter(y_test, pred)

# %%
actualPred(y_test, pred)

# %%
get_lag_corr(y_test, pred, 30)

# %%
### Next Steps

## Implement difference network
## Use with Neural Networks

# %%
### Implement Difference Network
## By subtracting T+0 from T+18
combined_df_difference = combined_df.copy()
combined_df_difference["Diff_y"] = combined_df_difference.iloc[:, -1] - combined_df_difference.iloc[:, -2]

# %%
combined_df_difference.head()
# Out:
#          0       1       2       3  ...     38      39      40  Diff_y
# 24  1596.0  1517.0  1486.0  1469.0  ... -116.0  1713.0  2167.0   454.0
# 25  1517.0  1486.0  1469.0  1472.0  ... -160.0  1647.0  2110.0   463.0
# 26  1486.0  1469.0  1472.0  1518.0  ... -227.0  1611.0  2062.0   451.0
# 27  1469.0  1472.0  1518.0  1598.0  ... -337.0  1608.0  1980.0   372.0
# 28  1472.0  1518.0  1598.0  1691.0  ... -338.0  1630.0  1861.0   231.0
#
# [5 rows x 42 columns]

# %%
combined_df_difference["Diff_y"][:5]
# Out:
# 24    454.0
# 25    463.0
# 26    451.0
# 27    372.0
# 28    231.0
# Name: Diff_y, dtype: float64

# %%
train_size = int(combined_df_difference.shape[0] * 0.8)
x_train, y_train = combined_df_difference.iloc[:train_size, :-3], combined_df_difference["Diff_y"][:train_size]
x_test, y_test = combined_df_difference.iloc[train_size:, :-3], combined_df_difference["Diff_y"][train_size:]

# %%
## Collect T+0
tzero_train = combined_df_difference.iloc[:train_size, -3]
tzero_test = combined_df_difference.iloc[train_size:, -3]

# %%
model_diff = xgboost.XGBRegressor(colsample_bytree=0.4,
                 objective="reg:squarederror",
                 max_depth=3,
                 n_estimators=100,                                                                    
                 seed=42)

# %%
model_diff.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4, gamma=0,
#              importance_type='gain', learning_rate=0.1, max_delta_step=0,
#              max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#              n_jobs=1, nthread=None, objective='reg:squarederror',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              seed=42, silent=None, subsample=1, verbosity=1)

# %%
pred = model_diff.predict(x_test)
pred = pred + tzero_test

# %%
mean_squared_error(y_train, model_diff.predict(x_train))
# Out:
# 41910.695248561016

# %%
mean_squared_error(y_test + tzero_test, pred)
# Out:
# 44573.72277366437

# %%
### Measures Lag of prediction

# %%
## Lag Measure

# z(delta) =  (y(t+delta) * y_hat(t)) / sig(y)*sig(y_hat)
# kendalltau spearmanr pearsonr

# %%
df["DAYTON_MW"]
# Out:
# Datetime
# 2004-12-31 01:00:00    1596.0
# 2004-12-31 02:00:00    1517.0
# 2004-12-31 03:00:00    1486.0
# 2004-12-31 04:00:00    1469.0
# 2004-12-31 05:00:00    1472.0
#                         ...
# 2018-01-01 20:00:00    2732.0
# 2018-01-01 21:00:00    2724.0
# 2018-01-01 22:00:00    2664.0
# 2018-01-01 23:00:00    2614.0
# 2018-01-02 00:00:00    2552.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
df["DAYTON_MW"].diff(1) ## Lag 24
# Out:
# Datetime
# 2004-12-31 01:00:00     NaN
# 2004-12-31 02:00:00   -79.0
# 2004-12-31 03:00:00   -31.0
# 2004-12-31 04:00:00   -17.0
# 2004-12-31 05:00:00     3.0
#                        ...
# 2018-01-01 20:00:00    18.0
# 2018-01-01 21:00:00    -8.0
# 2018-01-01 22:00:00   -60.0
# 2018-01-01 23:00:00   -50.0
# 2018-01-02 00:00:00   -62.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
df["DAYTON_MW"].shift(1)
# Out:
# Datetime
# 2004-12-31 01:00:00       NaN
# 2004-12-31 02:00:00    1596.0
# 2004-12-31 03:00:00    1517.0
# 2004-12-31 04:00:00    1486.0
# 2004-12-31 05:00:00    1469.0
#                         ...
# 2018-01-01 20:00:00    2714.0
# 2018-01-01 21:00:00    2732.0
# 2018-01-01 22:00:00    2724.0
# 2018-01-01 23:00:00    2664.0
# 2018-01-02 00:00:00    2614.0
# Name: DAYTON_MW, Length: 121275, dtype: float64

# %%
window_list(df["DAYTON_MW"], 5)
# Out:
# array([[  nan,   nan,   nan,   nan,   nan],
#        [  nan,   nan,   nan,   nan, 1596.],
#        [  nan,   nan,   nan, 1596., 1517.],
#        ...,
#        [2441., 2617., 2714., 2732., 2724.],
#        [2617., 2714., 2732., 2724., 2664.],
#        [2714., 2732., 2724., 2664., 2614.]])

# %%
window_list(df["DAYTON_MW"], 168).shape
# Out:
# (121275, 168)

# %%
cut_final(pd.DataFrame(window_list(df["DAYTON_MW"], 168)))
# Out:
#            0       1       2       3    ...     164     165     166     167
# 168     1596.0  1517.0  1486.0  1469.0  ...  2180.0  2138.0  2069.0  1960.0
# 169     1517.0  1486.0  1469.0  1472.0  ...  2138.0  2069.0  1960.0  2035.0
# 170     1486.0  1469.0  1472.0  1518.0  ...  2069.0  1960.0  2035.0  1968.0
# 171     1469.0  1472.0  1518.0  1598.0  ...  1960.0  2035.0  1968.0  1950.0
# 172     1472.0  1518.0  1598.0  1691.0  ...  2035.0  1968.0  1950.0  1954.0
# ...        ...     ...     ...     ...  ...     ...     ...     ...     ...
# 121269  2547.0  2494.0  2428.0  2334.0  ...  2372.0  2384.0  2441.0  2617.0
# 121270  2494.0  2428.0  2334.0  2225.0  ...  2384.0  2441.0  2617.0  2714.0
# 121271  2428.0  2334.0  2225.0  2105.0  ...  2441.0  2617.0  2714.0  2732.0
# 121272  2334.0  2225.0  2105.0  2396.0  ...  2617.0  2714.0  2732.0  2724.0
# 121273  2225.0  2105.0  2396.0  2362.0  ...  2714.0  2732.0  2724.0  2664.0
#
# [121106 rows x 168 columns]

# %%
## MAE RMSE MSE etc
